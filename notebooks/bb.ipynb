# %%
import pandas as pd
import os
import openpyxl

# %%
os.getcwd()
# Out:
# 'c:\\Users\\PCCOM\\Desktop\\TheBridge\\Alumno'

# %%
one = pd.read_csv("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\W Race Record.csv", encoding="utf-16", sep= "\t")

one
# Out:
#                    Race  # Games   # Wins  # Draws  # Losses Prom. Win %  \
# 0                Amazon    2.117  894.000  520.000   703.000       54,5%
# 1             Black Orc    3.181    1.018  714.000     1.449       43,2%
# 2            Bretonnian    6.000    1.000    2.000     3.000       33,3%
# 3          Chaos Chosen    2.170  701.000  530.000   939.000       44,5%
# 4           Chaos Dwarf    3.402    1.350  873.000     1.179       52,5%
# 5        Chaos Renegade    1.877  696.000  456.000   725.000       49,2%
# 6     Daemons of Khorne  335.000  118.000   84.000   133.000       47,8%
# 7              Dark Elf    3.417    1.426  822.000     1.169       53,8%
# 8                 Draft    4.000      NaN      NaN     4.000        0,0%
# 9                 Dwarf    4.352    1.784    1.057     1.511       53,1%
# 10            Elf Union    1.533  617.000  346.000   570.000       51,5%
# 11               Goblin    2.469  744.000  498.000     1.227       40,2%
# ...

# %%
two = pd.read_csv("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\WGridNums.csv", encoding="utf-16", sep= "\t")

two #winrates vs other races
# Out:
#                 Race Amazons Bretonnians  Chaos Chaos Dwarves Chaos Pact  \
# 0            Amazons   50,0%       81,3%  64,7%         46,9%      40,0%
# 1        Bretonnians   18,8%       50,0%  42,9%         83,3%      33,3%
# 2              Chaos   35,3%       57,1%  50,0%         73,0%      52,8%
# 3      Chaos Dwarves   53,1%       16,7%  27,0%         50,0%      35,0%
# 4         Chaos Pact   60,0%       66,7%  47,2%         65,0%      50,0%
# 5         Dark Elves   50,0%       67,9%  49,6%         45,8%      45,8%
# 6            Dwarves   61,5%       40,0%  30,4%         50,0%      45,5%
# 7              Elves   47,6%       43,8%  59,8%         47,6%      66,7%
# 8            Goblins   42,3%       31,3%  26,1%         55,0%      33,3%
# 9          Halflings   10,0%       50,0%  42,6%         12,5%      61,1%
# 10        High Elves   25,0%       66,7%  43,1%         50,0%      80,0%
# 11            Humans   49,3%       53,3%  42,9%         51,5%      65,6%
# ...

# %%
three = pd.read_csv("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\W Race Record(1).csv", encoding="utf-16", sep= "\t")

three #Eurobowl22
# Out:
#                    Race  # Games  # Wins  # Draws  # Losses Prom. Win %  \
# 0                Amazon  114.000      40       38        36       51,8%
# 1             Black Orc   30.000       7        8        15       36,7%
# 2          Chaos Chosen   30.000       7       11        12       41,7%
# 3           Chaos Dwarf  102.000      32       34        36       48,0%
# 4        Chaos Renegade   36.000      14        7        15       48,6%
# 5              Dark Elf  192.000      91       47        54       59,6%
# 6                 Dwarf  138.000      53       49        36       56,2%
# 7             Elf Union   42.000      16       11        15       51,2%
# 8                Goblin   24.000       9        2        13       41,7%
# 9              Halfling   36.000      15        8        13       52,8%
# 10             High Elf  198.000      73       61        64       52,3%
# 11                Human   90.000      28       20        42       42,2%
# ...

# %%
four = pd.read_csv("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\Race Table.csv", encoding="utf-16", sep= "\t")

four
# Out:
#    Race In                 Race  Number of Games (Tournament) (copy)  \
# 0       Am               Amazon                                  122
# 1       BO            Black Orc                                   39
# 2       CC         Chaos Chosen                                   39
# 3       CD          Chaos Dwarf                                  107
# 4       CR       Chaos Renegade                                   36
# 5       DE             Dark Elf                                  195
# 6       Dw                Dwarf                                  147
# 7       EU            Elf Union                                   42
# 8       Go               Goblin                                   42
# 9       Ha             Halfling                                   42
# 10      HE             High Elf                                  198
# 11      Hu                Human                                   96
# 12      IN    Imperial Nobility                                   36
# ...

# %%
five = pd.read_csv("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\Race Success and Popularity.csv", encoding="utf-16", sep= "\t")

five #same as 4
# Out:
#                    Race Race In               Race.1  \
# 0                Amazon      Am               Amazon
# 1             Black Orc      BO            Black Orc
# 2          Chaos Chosen      CC         Chaos Chosen
# 3           Chaos Dwarf      CD          Chaos Dwarf
# 4        Chaos Renegade      CR       Chaos Renegade
# 5              Dark Elf      DE             Dark Elf
# 6                 Dwarf      Dw                Dwarf
# 7             Elf Union      EU            Elf Union
# 8                Goblin      Go               Goblin
# 9              Halfling      Ha             Halfling
# 10             High Elf      HE             High Elf
# 11                Human      Hu                Human
# 12    Imperial Nobility      IN    Imperial Nobility
# 13               Khorne      Kh               Khorne
# 14            Lizardmen      Li            Lizardmen
# 15   Necromantic Horror      NH   Necromantic Horror
# 16                Norse      No                Norse
# ...

# %%
six = pd.read_csv("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\Prize Winners.csv", encoding="utf-16", sep= "\t")

six
# Out:
#     Unnamed: 0       Unnamed: 1       Unnamed: 2           Unnamed: 3       1  \
# 0         Race            Prize       Tournament                  NaN  Winner
# 1       Amazon     Best Painted                *        Distinct Wins     NaN
# 2       Amazon     Best Painted                *  Número de registros     NaN
# 3       Amazon  Most Casualties                *        Distinct Wins     NaN
# 4       Amazon  Most Casualties                *  Número de registros     NaN
# ..         ...              ...              ...                  ...     ...
# 410   Wood Elf        Runner up                *  Número de registros     NaN
# 411   Wood Elf       Stunty Cup  Brick Bowl 2020        Distinct Wins     NaN
# 412   Wood Elf       Stunty Cup  Brick Bowl 2020  Número de registros     NaN
# 413   Wood Elf           Winner                *        Distinct Wins     1,0
# 414   Wood Elf           Winner                *  Número de registros   369,0
#
# ...

# %%
seven = pd.read_csv("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\df_matches.csv")

seven #2020-22
# Out:
#         Unnamed: 0  match_id  replay_id  tournament_id  match_date match_time  \
# 0                0   4216259  1334297.0            0.0  2020-08-01   22:50:05
# 1                1   4216260  1334305.0            0.0  2020-08-01   22:50:14
# 2                2   4216261  1334304.0            0.0  2020-08-01   22:51:25
# 3                3   4216262  1334313.0            0.0  2020-08-01   22:53:07
# 4                4   4216263  1334291.0        51859.0  2020-08-01   22:58:57
# ...            ...       ...        ...            ...         ...        ...
# 170138      170138   4386466  1534254.0            0.0  2022-06-06   21:14:58
# 170139      170139   4386467  1534250.0        57758.0  2022-06-06   21:17:48
# 170140      170140   4386468  1534237.0        57746.0  2022-06-06   21:21:42
# 170141      170141   4386469  1534239.0            0.0  2022-06-06   21:25:02
# 170142      170142   4386470  1534248.0        57206.0  2022-06-06   21:25:33
#
# ...

# %%
eight = pd.read_csv("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\df_mbt.csv")

eight #2020-22
# Out:
#         Unnamed: 0  match_id  match_date  week_number  year week_year  \
# 0                0   4216259  2020-08-01           31  2020   2020-31
# 1                1   4216260  2020-08-01           31  2020   2020-31
# 2                2   4216261  2020-08-01           31  2020   2020-31
# 3                3   4216262  2020-08-01           31  2020   2020-31
# 4                4   4216263  2020-08-01           31  2020   2020-31
# ...            ...       ...         ...          ...   ...       ...
# 340281      340281   4386466  2022-06-06           23  2022   2022-23
# 340282      340282   4386467  2022-06-06           23  2022   2022-23
# 340283      340283   4386468  2022-06-06           23  2022   2022-23
# 340284      340284   4386469  2022-06-06           23  2022   2022-23
# 340285      340285   4386470  2022-06-06           23  2022   2022-23
#
#          week_date    team_id  ruleset  league  ...  cr_diff2 games_played  \
# ...

# %%
nine = pd.read_csv("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\NAF_Matches_2013_14reduced.csv")

nine #2013-14 pre 2020
# Out:
#       tournamentnation  gameid  HomeCoachNAFid       HomeRace  goalshome  \
# 0               France  112109            8557  Chaos Dwarves          0
# 1               France  112110           19454    Necromantic          1
# 2               France  112111           18851     Chaos Pact          1
# 3               France  112112           20269            Orc          1
# 4               France  112113           13455     Dark Elves          1
# ...                ...     ...             ...            ...        ...
# 32975      New Zealand  125750           20866      Lizardmen          1
# 32976      New Zealand  125751           18989         Khemri          0
# 32977      New Zealand  125752           18141     Wood Elves          3
# 32978      New Zealand  125753           20154      Halflings          1
# 32979      New Zealand  125754            2726    Necromantic          2
#
#        AwayCoachNAFid       AwayRace  goalsaway    gamedate
# ...

# %%
import openpyxl

ten = pd.read_excel("C:\\Users\\PCCOM\\Desktop\\TheBridge\\BB_CSV\\races.xlsx")

ten #pre 2020 http://anbbl.99012099.no/races.html
# Out:
#      #               Unnamed: 1   GP   W   D   L    P/GP  TD    +    -  Cas  \
# 0    1              Skaven (19)  191  97  30  64  58.64%  90  437  347 -169
# 1    2            Dark Elf (18)  194  94  36  64  57.73%  72  365  293  -73
# 2    3            Lizardmen (9)  110  48  27  35  55.91%  18  196  178  -15
# 3    4               Human (17)  125  60  18  47  55.20%  30  223  193   61
# 4    5            Wood Elf (14)  146  69  22  55  54.79%  74  347  273 -155
# 5    6  Necromantic Horror (14)  126  56  25  45  54.37%  20  208  188   61
# 6    7     Shambling Undead (9)   82  34  17  31  51.83%  -1  134  135   63
# 7    8          Elven Union (6)   37  16   6  15  51.35%  -1   84   85  -75
# 8    9          Chaos Dwarf (7)   96  38  20  38  50.00%  -8  118  126   95
# 9   10        Chaos Chosen (12)  122  51  19  52  49.59% -22  166  188  112
# 10  11                Dwarf (8)   87  35  13  39  47.70% -11  105  116  152
# ...

# %%
#para investigar
https://github.com/ketilkn/naf-data
https://fumbbl.com/p/stats
https://public.tableau.com/app/profile/mike.sann0638.davies#!/
