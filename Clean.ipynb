# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as plotly
import seaborn as sns

# %% [markdown]
# # Dataset 1 (Partidos entre 2020-2022)

# %%
WR = pd.read_csv("data/W Race Record.csv", index_col='Race', encoding="utf-16", sep= "\t")

WR #Partidos oficiales BB 2020 entre los años 2020 a 2022
# Out:
#                      # Games   # Wins  # Draws  # Losses Prom. Win %  TDs For  \
# Race
# Amazon                2117.0    894.0    520.0    703,00      54,50%   2429.0
# Black Orc             3181.0   1018.0    714.0   1449,00      43,20%   2929.0
# Bretonnian               6.0      1.0      2.0      3,00      33,30%      4.0
# Chaos Chosen          2170.0    701.0    530.0    939,00      44,50%   2065.0
# Chaos Dwarf           3402.0   1350.0    873.0   1179,00      52,50%   3639.0
# Chaos Renegade        1877.0    696.0    456.0    725,00      49,20%   2070.0
# Daemons of Khorne      335.0    118.0     84.0    133,00      47,80%    362.0
# Dark Elf              3417.0   1426.0    822.0   1169,00      53,80%   4370.0
# Dwarf                 4352.0   1784.0   1057.0   1511,00      53,10%   4499.0
# Elf Union             1533.0    617.0    346.0    570,00      51,50%   2225.0
# Goblin                2469.0    744.0    498.0   1227,00      40,20%   2460.0
# ...

# %%
WR['TDs Net'] = WR['TDs Net'].str.replace(',00','') #Quitar los ,00 del "float" para poder pasarlos a float reales
WR['# Losses'] = WR['# Losses'].str.replace(',00','')

# %%
WR['Prom. Win %'] = WR['Prom. Win %'].map(lambda x: x.rstrip('%')) #Quitar los % y cambiar la coma a punto para poder operar más adelante.
WR['Prom. Win %'] = WR['Prom. Win %'].str.replace(',','.')
WR['Prom. Win %'] = WR['Prom. Win %'].astype(float)

# %%
WR['# Losses'] = WR['# Losses'].astype(float)
WR['TDs Net'] = WR['TDs Net'].astype(float)

# %%
WR #visualización final del dataset1
# Out:
#                      # Games   # Wins  # Draws  # Losses  Prom. Win %  \
# Race
# Amazon                2117.0    894.0    520.0     703.0         54.5
# Black Orc             3181.0   1018.0    714.0    1449.0         43.2
# Bretonnian               6.0      1.0      2.0       3.0         33.3
# Chaos Chosen          2170.0    701.0    530.0     939.0         44.5
# Chaos Dwarf           3402.0   1350.0    873.0    1179.0         52.5
# Chaos Renegade        1877.0    696.0    456.0     725.0         49.2
# Daemons of Khorne      335.0    118.0     84.0     133.0         47.8
# Dark Elf              3417.0   1426.0    822.0    1169.0         53.8
# Dwarf                 4352.0   1784.0   1057.0    1511.0         53.1
# Elf Union             1533.0    617.0    346.0     570.0         51.5
# Goblin                2469.0    744.0    498.0    1227.0         40.2
# Halfling              2808.0    982.0    635.0    1191.0         46.3
# ...

# %% [markdown]
# # Dataset 2 (Eurobowl22)

# %%
WR2 = pd.read_csv("data/W Race Record(1).csv", index_col='Race', encoding="utf-16", sep= "\t")

WR2 #df sobre el mundial Eurobowl22
# Out:
#                      # Games  # Wins # Draws # Losses Prom. Win %  TDs For  \
# Race
# Amazon                114,00   40,00   38,00    36,00      51,80%   110,00
# Black Orc              30,00    7,00    8,00    15,00      36,70%    21,00
# Chaos Chosen           30,00    7,00   11,00    12,00      41,70%    26,00
# Chaos Dwarf           102,00   32,00   34,00    36,00      48,00%    93,00
# Chaos Renegade         36,00   14,00    7,00    15,00      48,60%    39,00
# Dark Elf              192,00   91,00   47,00    54,00      59,60%   232,00
# Dwarf                 138,00   53,00   49,00    36,00      56,20%   139,00
# Elf Union              42,00   16,00   11,00    15,00      51,20%    60,00
# Goblin                 24,00    9,00    2,00    13,00      41,70%    20,00
# Halfling               36,00   15,00    8,00    13,00      52,80%    45,00
# High Elf              198,00   73,00   61,00    64,00      52,30%   247,00
# ...

# %%
WR2['# Games'] = WR2['# Games'].str.replace(',00','')
WR2['# Wins'] = WR2['# Wins'].str.replace(',00','')
WR2['# Draws'] = WR2['# Draws'].str.replace(',00','')
WR2['# Losses'] = WR2['# Losses'].str.replace(',00','')
WR2['TDs For'] = WR2['TDs For'].str.replace(',00','')
WR2['TDs Against'] = WR2['TDs Against'].str.replace(',00','')
WR2['TDs Net'] = WR2['TDs Net'].str.replace(',00','')
WR2['Prom. TDs For'] = WR2['Prom. TDs For'].str.replace(',','.')
WR2['Prom. TDs Against'] = WR2['Prom. TDs Against'].str.replace(',','.')
#lo mismo que antes, quitar las comas de los strings para poder pasarlos a float

# %%
WR2['Prom. Win %'] = WR2['Prom. Win %'].map(lambda x: x.rstrip('%')) #adaptar la columna de % para pasarlo a float
WR2['Prom. Win %'] = WR2['Prom. Win %'].str.replace(',','.')
WR2['Prom. Win %'] = WR2['Prom. Win %'].astype(float)

# %%
WR2['# Games'] = WR2['# Games'].astype(float)
WR2['# Wins'] = WR2['# Wins'].astype(float)
WR2['# Draws'] = WR2['# Draws'].astype(float)
WR2['# Losses'] = WR2['# Losses'].astype(float)
WR2['TDs Net'] = WR2['TDs Net'].astype(float)
WR2['TDs For'] = WR2['TDs For'].astype(float)
WR2['TDs Against'] = WR2['TDs Against'].astype(float)
WR2['Prom. TDs For'] = WR2['Prom. TDs For'].astype(float)
WR2['Prom. TDs Against'] = WR2['Prom. TDs Against'].astype(float)
#cambio de str a float de todas las columnas

# %% [markdown]
# # Unión

# %%
WR3 = WR #creación de "copia" para no tener que volver a rehacer todo lo anterior

# %%
WRdef = pd.concat([WR3, WR2]).groupby(['Race']).sum().reset_index() #unión de los dos datasets

WRdef
# Out:
#                    Race  # Games   # Wins  # Draws  # Losses  Prom. Win %  \
# 0                Amazon   2231.0    934.0    558.0     739.0        106.3
# 1             Black Orc   3211.0   1025.0    722.0    1464.0         79.9
# 2            Bretonnian      6.0      1.0      2.0       3.0         33.3
# 3          Chaos Chosen   2200.0    708.0    541.0     951.0         86.2
# 4           Chaos Dwarf   3504.0   1382.0    907.0    1215.0        100.5
# 5        Chaos Renegade   1913.0    710.0    463.0     740.0         97.8
# 6     Daemons of Khorne    335.0    118.0     84.0     133.0         47.8
# 7              Dark Elf   3609.0   1517.0    869.0    1223.0        113.4
# 8                 Dwarf   4490.0   1837.0   1106.0    1547.0        109.3
# 9             Elf Union   1575.0    633.0    357.0     585.0        102.7
# 10               Goblin   2493.0    753.0    500.0    1240.0         81.9
# 11             Halfling   2844.0    997.0    643.0    1204.0         99.1
# ...

# %%
WRdef["Prom. Win %"] = WRdef["Prom. Win %"] / 2 # como solo hemos sumado en la columna del porcentaje de victorias, hay que dividirlo entre el número de datasets

WRdef
# Out:
#                    Race  # Games   # Wins  # Draws  # Losses  Prom. Win %  \
# 0                Amazon   2231.0    934.0    558.0     739.0        53.15
# 1             Black Orc   3211.0   1025.0    722.0    1464.0        39.95
# 2            Bretonnian      6.0      1.0      2.0       3.0        16.65
# 3          Chaos Chosen   2200.0    708.0    541.0     951.0        43.10
# 4           Chaos Dwarf   3504.0   1382.0    907.0    1215.0        50.25
# 5        Chaos Renegade   1913.0    710.0    463.0     740.0        48.90
# 6     Daemons of Khorne    335.0    118.0     84.0     133.0        23.90
# 7              Dark Elf   3609.0   1517.0    869.0    1223.0        56.70
# 8                 Dwarf   4490.0   1837.0   1106.0    1547.0        54.65
# 9             Elf Union   1575.0    633.0    357.0     585.0        51.35
# 10               Goblin   2493.0    753.0    500.0    1240.0        40.95
# 11             Halfling   2844.0    997.0    643.0    1204.0        49.55
# ...

# %%
WRfinal = WRdef.drop([2, 6, 17, 29]) # quito 4 filas de equipos/total general no relevantes
WRfinal.set_index('Race')
# Out:
#                      # Games  # Wins  # Draws  # Losses  Prom. Win %  TDs For  \
# Race
# Amazon                2231.0   934.0    558.0     739.0        53.15   2539.0
# Black Orc             3211.0  1025.0    722.0    1464.0        39.95   2950.0
# Chaos Chosen          2200.0   708.0    541.0     951.0        43.10   2091.0
# Chaos Dwarf           3504.0  1382.0    907.0    1215.0        50.25   3732.0
# Chaos Renegade        1913.0   710.0    463.0     740.0        48.90   2109.0
# Dark Elf              3609.0  1517.0    869.0    1223.0        56.70   4602.0
# Dwarf                 4490.0  1837.0   1106.0    1547.0        54.65   4638.0
# Elf Union             1575.0   633.0    357.0     585.0        51.35   2285.0
# Goblin                2493.0   753.0    500.0    1240.0        40.95   2480.0
# Halfling              2844.0   997.0    643.0    1204.0        49.55   3363.0
# High Elf              2153.0   942.0    531.0     680.0        54.40   3119.0
# ...

# %%
#WRfinal.sort_values(by='Prom. Win %', ascending=False) #visualización de prueba para ver qué raza tiene mayor porcentaje de victorias

# %%
#WRfinal.sort_values(by='# Games') #prueba con número de partidos jugados, del menos popular al que más

# %%
WRfinal.to_csv('data/ESTADISTICAS.csv', index=False) #creación del archivo csv final

# %%
WRfinal.to_excel('data/ESTADISTICAS.xlsx', index=False)

# %%
plt.figure(figsize=(15,15)) #heatmap del df original
sns.heatmap(WRfinal.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);

# %% [markdown]
# # Before 2020

# %%
bef = pd.read_excel("data/before.xlsx")

bef #Partidos oficiales ANTES de 2020
# Out:
#                    Race  # Games  # Wins  # Draws  # Losses  Prom. Win %  \
# 0                Amazon    19945    8426     4639      6880         53.9
# 1            Bretonnian     3386    1414      774      1198         53.2
# 2          Chaos Chosen    15672    5473     3388      6811         45.7
# 3           Chaos Dwarf    25593   10374     5904      9315         52.1
# 4        Chaos Renegade     9929    3619     2328      3982         48.2
# 5     Daemons of Khorne     2242     801      464       977         46.1
# 6              Dark Elf    33712   14275     7446     11991         53.4
# 7                 Dwarf    35772   14137     8359     13276         51.2
# 8             Elf Union    14084    5797     2962      5325         51.7
# 9                Goblin    16402    3965     2873      9564         32.9
# 10             Halfling    13158    3342     2815      7001         36.1
# 11             High Elf    10365    4049     2142      4174         49.4
# ...

# %%
bef['# Games'] = bef['# Games'].astype(float)
bef['# Wins'] = bef['# Wins'].astype(float)
bef['# Draws'] = bef['# Draws'].astype(float)
bef['# Losses'] = bef['# Losses'].astype(float)
bef['TDs Net'] = bef['TDs Net'].astype(float)
bef['TDs Against'] = bef['TDs Against'].astype(float)
bef['TDs For'] = bef['TDs For'].astype(float)

# %%
bef.to_excel('data/BEF.xlsx', index=False) #los excels parece que Tableau los lee mejor

# %%
#bef.sort_values(by="Prom. Win %", ascending=False) #para ver si todo estaba correcto

# %% [markdown]
# # Win df

# %%
wint = pd.read_excel("data/ganadoresNAF.xlsx")

wint #df con el número de torneos ganados, segundos puestos, Touchdowns y bajas según la raza.
# Out:
#                    Race  Winner  RunnerUp  MostTD  MostCas
# 0                Amazon      39        24      13       11
# 1             Black Orc      20        30      14       46
# 2          Chaos Chosen      13        20       7       26
# 3           Chaos Dwarf      48        43      20       47
# 4        Chaos Renegade      11        12       9       28
# 5     Daemons of Khorne      17        18       7       41
# 6              Dark Elf      46        35      52        8
# 7                 Dwarf      63        65      27       83
# 8             Elf Union      10        13      40        0
# 9                Goblin      14        10       7       33
# 10             Halfling      22        22      22       42
# 11             High Elf      35        28      39        3
# 12                Human      30        22      27       16
# 13    Imperial Nobility      15        14      10        8
# 14            Lizardmen      41        52      45       28
# ...

# %%
wint['SumPole'] = wint['Winner']+ wint['RunnerUp']

wint #Creación de nueva columna que suma victorias y segundos puestos
# Out:
#                    Race  Winner  RunnerUp  MostTD  MostCas  SumPole
# 0                Amazon      39        24      13       11       63
# 1             Black Orc      20        30      14       46       50
# 2          Chaos Chosen      13        20       7       26       33
# 3           Chaos Dwarf      48        43      20       47       91
# 4        Chaos Renegade      11        12       9       28       23
# 5     Daemons of Khorne      17        18       7       41       35
# 6              Dark Elf      46        35      52        8       81
# 7                 Dwarf      63        65      27       83      128
# 8             Elf Union      10        13      40        0       23
# 9                Goblin      14        10       7       33       24
# 10             Halfling      22        22      22       42       44
# 11             High Elf      35        28      39        3       63
# 12                Human      30        22      27       16       52
# ...

# %%
#wint.sort_values(["Winner", "RunnerUp"], ascending=[False, False]) #El que más victorias tiene es Underworld

# %%
#wint.sort_values(by='SumPole', ascending=False) #Pero en sumatorio de victorias y segundos puestos, los enanos suben al primer puesto.

# %% [markdown]
# # Filtrado de Win para Dwarf

# %%
dwW = wint.loc[[6,7,8,11,28],:]
dwW.drop(['MostTD'],axis=1, inplace=True)
dwW.drop(['MostCas'],axis=1, inplace=True) #filtrado para quedarme con enanos y elfos

# %%
dwW
# Out:
#          Race  Winner  RunnerUp  SumPole
# 6    Dark Elf      46        35       81
# 7       Dwarf      63        65      128
# 8   Elf Union      10        13       23
# 11   High Elf      35        28       63
# 28   Wood Elf      30        19       49

# %%
plt.style.use('dark_background')

# %%
df_pie = dwW[['Race','Winner', 'RunnerUp']]

df_pie['Win_Percentage'] = ((df_pie['Winner'] + df_pie['RunnerUp']) * 100 / 344)
colors = ["darkslategray", "navy", "chocolate", "dodgerblue", "forestgreen"]
myexplode = [0, 0.09, 0, 0, 0]
# Crear círculo para el centro
"""
my_circle=plt.Circle( (0,0),
                     0.7, # Grosor del donut
                     color='black')
"""

plt.figure(figsize=(8,8))

plt.pie(df_pie['Win_Percentage'], pctdistance=0.85, labeldistance=1.1, labels=df_pie['Race'], textprops={'fontsize': 14},
        explode=myexplode, colors=colors, wedgeprops = { 'linewidth' : 1.5, 'edgecolor' : 'black' }, autopct='%1.1f%%');
plt.title('Dwarf vs Elves, likeliness to win a Tournament')
p=plt.gcf()
#p.gca().add_artist(my_circle);

# %% [markdown]
# # % df

# %%
percent = pd.read_csv("data/porcentajesAfter.csv", encoding="utf-16", sep= "\t")

percent #porcentaje de victorias dependiendo del equipo rival
# Out:
#                    Race  Amazon Black Orc Chaos Chosen Chaos Dwarf  \
# 0                Amazon  50,00%    58,70%       66,70%      35,90%
# 1             Black Orc  41,30%    50,00%       47,40%      36,50%
# 2          Chaos Chosen  33,30%    52,60%       50,00%      60,90%
# 3           Chaos Dwarf  64,10%    63,50%       39,10%      50,00%
# 4        Chaos Renegade  46,20%    77,80%       47,60%      51,60%
# 5     Daemons of Khorne  62,50%    43,50%       38,50%      34,60%
# 6              Dark Elf  69,20%    51,30%       46,10%      39,50%
# 7                 Dwarf  69,20%    49,30%       54,80%      52,90%
# 8             Elf Union  25,00%    53,70%       60,90%      57,90%
# 9                Goblin  25,00%    56,10%       37,90%      19,60%
# 10             Halfling  34,30%    61,50%       53,40%      43,30%
# 11             High Elf  52,80%    61,10%       61,80%      50,00%
# 12                Human  39,70%    46,40%       55,90%      43,50%
# ...

# %%
percentd = percent.drop(["Amazon", "Black Orc", "Chaos Chosen", "Chaos Dwarf", "Chaos Renegade", "Daemons of Khorne", "Goblin", "Halfling", "Human",
                        "Imperial Nobility", "Lizardmen", "Necromantic Horror", "Norse", "Nurgle", "Ogre", "Old World Alliance", "Orc", "Shambling Undead", 
                        "Skaven", "Slann", "Snotling", "Tomb Kings", "Underworld Denizens", "Vampire"], axis=1)

# %%
percentd2 = percentd.drop(percentd.index[0:6])
percentd2 = percentd2.drop(percentd.index[9:11])
percentd2 = percentd2.drop(percentd.index[12:28]) #filtrado de porcentajes para quedarme con enanos y elfos

# %%
percentd2.to_excel('data/dwrf.xlsx', index=False) #los excels parece que Tableau los lee mejor

# %% [markdown]
# # Filtrado de % para Dwarf

# %%
dwarf = pd.read_excel("data/dwrf.xlsx")

dwarf
# Out:
#         Race Dark Elf   Dwarf Elf Union High Elf Wood Elf
# 0   Dark Elf   50,00%  30,00%    52,40%   57,50%   58,90%
# 1      Dwarf   70,00%  50,00%    50,00%   46,70%   65,50%
# 2  Elf Union   47,60%  50,00%    50,00%   38,90%   50,00%
# 3   High Elf   42,50%  53,30%    61,10%   50,00%   50,00%
# 4   Wood Elf   41,10%  34,50%    50,00%   50,00%   50,00%

# %%
dwarf = dwarf.replace(',', '.', regex=True)
dwarf = dwarf.replace('%', '', regex=True)
dwarf['Dark Elf'] = dwarf['Dark Elf'].astype(float)
dwarf['Dwarf'] = dwarf['Dwarf'].astype(float)
dwarf['Elf Union'] = dwarf['Elf Union'].astype(float)
dwarf['High Elf'] = dwarf['High Elf'].astype(float)
dwarf['Wood Elf'] = dwarf['Wood Elf'].astype(float)

# %%
df_dwarf_elfs = dwarf[dwarf['Race'] == 'Dwarf'][['Dark Elf', 'Elf Union', 'High Elf', 'Wood Elf']]

# victorias de enanos vs cada equipo de elfos
df_dwarf_elfs = df_dwarf_elfs.transpose()

ax = plt.bar(df_dwarf_elfs.index, df_dwarf_elfs[1], edgecolor='lightsteelblue', color="darkgreen")
plt.ylabel('Win Percentage')
plt.xlabel('Dwarf VS')
plt.ylim(0, 100)
plt.xlim(-0.5, 3.5)
plt.title('Dwarf vs Elven Teams')
for x, y in zip(df_dwarf_elfs.index, df_dwarf_elfs[1]):
    plt.text(x, y + 2, str(y)+'%', ha='center', va='bottom', fontsize=17);

# %%
plotly.bar(df_dwarf_elfs) #pruebo a hacerlo con plotly por si fuera mejor

# %%
percent.head(8)
# Out:
#                 Race  Amazon Black Orc Chaos Chosen Chaos Dwarf  \
# 0             Amazon  50,00%    58,70%       66,70%      35,90%
# 1          Black Orc  41,30%    50,00%       47,40%      36,50%
# 2       Chaos Chosen  33,30%    52,60%       50,00%      60,90%
# 3        Chaos Dwarf  64,10%    63,50%       39,10%      50,00%
# 4     Chaos Renegade  46,20%    77,80%       47,60%      51,60%
# 5  Daemons of Khorne  62,50%    43,50%       38,50%      34,60%
# 6           Dark Elf  69,20%    51,30%       46,10%      39,50%
# 7              Dwarf  69,20%    49,30%       54,80%      52,90%
#
#   Chaos Renegade Daemons of Khorne Dark Elf   Dwarf Elf Union  ...  \
# 0         53,80%            37,50%   30,80%  30,80%    75,00%  ...
# 1         22,20%            56,50%   48,80%  50,70%    46,30%  ...
# 2         52,40%            61,50%   53,90%  45,20%    39,10%  ...
# 3         48,40%            65,40%   60,50%  47,10%    42,10%  ...
# ...

# %%
df_dwarf_lose = percent[percent['Race'] == 'Dwarf'][['Black Orc', 'Orc', 'Shambling Undead', 'Vampire']]

df_dwarf_lose = df_dwarf_lose.replace(',', '.', regex=True)
df_dwarf_lose = df_dwarf_lose.replace('%', '', regex=True)
df_dwarf_lose['Black Orc'] = df_dwarf_lose['Black Orc'].astype(float)
df_dwarf_lose['Orc'] = df_dwarf_lose['Orc'].astype(float)
df_dwarf_lose['Shambling Undead'] = df_dwarf_lose['Shambling Undead'].astype(float)
df_dwarf_lose['Vampire'] = df_dwarf_lose['Vampire'].astype(float)

# %%
# victorias de enanos vs equipos contra los que suele perder
df_dwarf_lose = df_dwarf_lose.transpose()
ec = ['gold', 'limegreen', 'turquoise', 'coral']

ax = plt.bar(df_dwarf_lose.index, df_dwarf_lose[7], edgecolor=ec, color="firebrick")
plt.ylabel('Win Percentage')
plt.xlabel('Dwarf VS')
plt.ylim(0, 100)
#plt.xlim(-0.5, 3.5)
plt.title('Dwarf vs Teams that beat them')
for x, y in zip(df_dwarf_lose.index, df_dwarf_lose[7]):
    plt.text(x, y + 2, str(y)+'%', ha='center', va='bottom', fontsize=17);

# %%
df_dwarf_h = percent[percent['Race'] == 'Dwarf'][['Lizardmen', 'Human', 'Underworld Denizens', 'Necromantic Horror', 'Skaven',]]
df_dwarf_h.rename(columns = {'Underworld Denizens': 'Underworld', 'Necromantic Horror': 'NecroH'}, inplace=True)

df_dwarf_h = df_dwarf_h.replace(',', '.', regex=True)
df_dwarf_h = df_dwarf_h.replace('%', '', regex=True)
df_dwarf_h['Lizardmen'] = df_dwarf_h['Lizardmen'].astype(float)
df_dwarf_h['Human'] = df_dwarf_h['Human'].astype(float)
df_dwarf_h['Underworld'] = df_dwarf_h['Underworld'].astype(float)
df_dwarf_h['NecroH'] = df_dwarf_h['NecroH'].astype(float)
df_dwarf_h['Skaven'] = df_dwarf_h['Skaven'].astype(float)

# %%
plt.style.use('grayscale')

# %%
# victorias de enanos vs equipos contra los que suele perder
df_dwarf_h = df_dwarf_h.transpose()
ec = ['yellow', 'yellow', 'yellow', 'yellow', 'yellow']

ax = plt.bar(df_dwarf_h.index, df_dwarf_h[7], edgecolor=ec, color="slateblue")
plt.ylabel('Win Percentage')
plt.xlabel('Dwarf VS')
plt.grid(b=None)
plt.ylim(0, 100)
#plt.xlim(0, 5)
plt.title('Why Dwarf teams win', color='black')
for x, y in zip(df_dwarf_h.index, df_dwarf_h[7]):
    plt.text(x, y + 2, str(y)+'%', ha='center', va='bottom', color='black', fontsize=17);
# Out:
# c:\Users\PCCOM\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   if __name__ == "__main__":
